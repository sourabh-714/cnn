# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
FAST_RUN=False
batch_size=32
epochs=100
if FAST_RUN:
    epochs=1

# %%
train_data = pd.read_csv("/content/gdrive/My Drive/digits/train.csv")
test_data = pd.read_csv("/content/gdrive/My Drive/digits/train.csv")

# %%
def show_image(train_image, label, index):
    image_shaped = train_image.values.reshape(28,28)
    plt.subplot(3, 6, index+1)
    plt.imshow(image_shaped, cmap=plt.cm.gray)
    plt.title(label)


plt.figure(figsize=(18, 8))
sample_image = train_data.sample(18).reset_index(drop=True)
for index, row in sample_image.iterrows():
    label = row['label']
    image_pixels = row.drop('label')
    show_image(image_pixels, label, index)
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

x = train_data.drop(columns=['label']).values.reshape(train_data.shape[0],28,28,1)
y = to_categorical(train_data['label'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=10,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)
train_datagen.fit(x_train)
train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=batch_size
)

validation_datagen = ImageDataGenerator(rescale=1./255)
train_datagen.fit(x_test)
validation_generator = validation_datagen.flow(
    x_test,
    y_test
    
)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

model = Sequential()
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
model.fit_generator(
    train_generator, 
    steps_per_epoch=len(x_train) // batch_size, 
    validation_data=validation_generator,
    validation_steps=len(x_test) // batch_size,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.3860 - accuracy: 0.8799 - val_loss: 0.0549 - val_accuracy: 0.9764
#
# Epoch 00001: val_loss improved from inf to 0.05493, saving model to model.h5
# Epoch 2/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.1653 - accuracy: 0.9509 - val_loss: 0.0505 - val_accuracy: 0.9786
#
# Epoch 00002: val_loss improved from 0.05493 to 0.05049, saving model to model.h5
# Epoch 3/100
# 1181/1181 [==============================] - 117s 99ms/step - loss: 0.1282 - accuracy: 0.9622 - val_loss: 0.0256 - val_accuracy: 0.9784
#
# Epoch 00003: val_loss improved from 0.05049 to 0.02556, saving model to model.h5
# Epoch 4/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.1121 - accuracy: 0.9660 - val_loss: 0.0184 - val_accuracy: 0.9844
#
# Epoch 00004: val_loss improved from 0.02556 to 0.01839, saving model to model.h5
# Epoch 5/100
# 1181/1181 [==============================] - 114s 97ms/step - loss: 0.1082 - accuracy: 0.9681 - val_loss: 0.0139 - val_accuracy: 0.9842
#
# Epoch 00005: val_loss improved from 0.01839 to 0.01388, saving model to model.h5
# Epoch 6/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.1006 - accuracy: 0.9710 - val_loss: 0.0075 - val_accuracy: 0.9834
#
# Epoch 00006: val_loss improved from 0.01388 to 0.00753, saving model to model.h5
# Epoch 7/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0938 - accuracy: 0.9739 - val_loss: 0.1177 - val_accuracy: 0.9861
#
# Epoch 00007: val_loss did not improve from 0.00753
# Epoch 8/100
# 1181/1181 [==============================] - 118s 100ms/step - loss: 0.0901 - accuracy: 0.9737 - val_loss: 0.1062 - val_accuracy: 0.9844
#
# Epoch 00008: val_loss did not improve from 0.00753
# Epoch 9/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0877 - accuracy: 0.9744 - val_loss: 0.0063 - val_accuracy: 0.9844
#
# Epoch 00009: val_loss improved from 0.00753 to 0.00628, saving model to model.h5
# Epoch 10/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0867 - accuracy: 0.9752 - val_loss: 0.0234 - val_accuracy: 0.9818
#
# Epoch 00010: val_loss did not improve from 0.00628
# Epoch 11/100
# 1181/1181 [==============================] - 114s 96ms/step - loss: 0.0858 - accuracy: 0.9748 - val_loss: 0.0297 - val_accuracy: 0.9856
#
# Epoch 00011: val_loss did not improve from 0.00628
# Epoch 12/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0844 - accuracy: 0.9757 - val_loss: 7.1943e-04 - val_accuracy: 0.9868
#
# Epoch 00012: val_loss improved from 0.00628 to 0.00072, saving model to model.h5
# Epoch 13/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0843 - accuracy: 0.9759 - val_loss: 0.0049 - val_accuracy: 0.9861
#
# Epoch 00013: val_loss did not improve from 0.00072
# Epoch 14/100
# 1181/1181 [==============================] - 117s 99ms/step - loss: 0.0842 - accuracy: 0.9757 - val_loss: 9.9951e-04 - val_accuracy: 0.9873
#
# Epoch 00014: val_loss did not improve from 0.00072
# Epoch 15/100
# 1181/1181 [==============================] - 112s 95ms/step - loss: 0.0819 - accuracy: 0.9761 - val_loss: 0.0085 - val_accuracy: 0.9834
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00015: val_loss did not improve from 0.00072
# Epoch 16/100
# 1181/1181 [==============================] - 112s 95ms/step - loss: 0.0653 - accuracy: 0.9808 - val_loss: 0.1331 - val_accuracy: 0.9887
#
# Epoch 00016: val_loss did not improve from 0.00072
# Epoch 17/100
# 1181/1181 [==============================] - 112s 95ms/step - loss: 0.0671 - accuracy: 0.9796 - val_loss: 0.2657 - val_accuracy: 0.9885
#
# Epoch 00017: val_loss did not improve from 0.00072
# Epoch 18/100
# 1181/1181 [==============================] - 113s 95ms/step - loss: 0.0635 - accuracy: 0.9811 - val_loss: 0.0355 - val_accuracy: 0.9873
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00018: val_loss did not improve from 0.00072
# Epoch 19/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0619 - accuracy: 0.9820 - val_loss: 0.0082 - val_accuracy: 0.9873
#
# Epoch 00019: val_loss did not improve from 0.00072
# Epoch 20/100
# 1181/1181 [==============================] - 113s 96ms/step - loss: 0.0621 - accuracy: 0.9812 - val_loss: 0.0017 - val_accuracy: 0.9880
#
# Epoch 00020: val_loss did not improve from 0.00072
# Epoch 21/100
# 1181/1181 [==============================] - 117s 99ms/step - loss: 0.0590 - accuracy: 0.9829 - val_loss: 0.0096 - val_accuracy: 0.9878
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00021: val_loss did not improve from 0.00072
# Epoch 22/100
# 1181/1181 [==============================] - 114s 97ms/step - loss: 0.0656 - accuracy: 0.9814 - val_loss: 0.3409 - val_accuracy: 0.9880
#
# Epoch 00022: val_loss did not improve from 0.00072
# Epoch 00022: early stopping

# %%
x_test_recaled = (x_test.astype("float32") / 255)
scores = model.evaluate(x_test_recaled, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("%s: %.2f%%" % (model.metrics_names[0], scores[0]*100))
# Out:
# accuracy: 98.81%
# loss: 4.25%
